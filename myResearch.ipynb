# %%
import numpy as np
from numpy import array, ndarray
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler,  Normalizer
import pandas as pd

# %%
dataFr = pd.read_csv('C:/Users/User/Desktop/ACM/OOZ2.csv', encoding='ISO-8859-1')

# %%
dataFr.head()
# Out:
#   Mahsulot turi        Y   wheat  barley   corn   rice  legumes  potato   \
# 0        1991 y    29.73   668.2   357.9  430.6  551.8      5.9    351.2
# 1        1992 y   216.40  1042.4   394.7  367.2  583.0      5.4    365.4
# 2        1993 y  1995.00   947.4   319.3  403.6  581.7      6.4    472.4
# 3        1994 y    32.80  1452.1   322.3  275.9  528.4      6.2    567.1
# 4        1995 y   124.40  2494.1   347.7  185.5  327.6      6.9    439.9
#
#    Sabzavotlar ? jami , ming tonna pomidor, ming tonna  ...  \
# 0                           3348.0               617.1  ...
# 1                           3494.3               526.8  ...
# 2                           3038.7               444.8  ...
# 3                           2975.3               487.8  ...
# 4                           2724.7               426.7  ...
#
#   parrandalar,tirik vaznda, ming tonna  \
# 0                                 62.8
# 1                                 36.4
# 2                                 29.9
# ...

# %%
data_X = array([dataFr['wheat'], dataFr['barley'], dataFr['corn'], dataFr['rice'], dataFr['legumes']])
data_y = array([dataFr['Y']])
print(data_y)
# Out:
# [[2.973000e+01 2.164000e+02 1.995000e+03 3.280000e+01 1.244000e+02
#   1.810000e+02 3.999000e+02 5.501000e+02 8.915000e+02 1.387200e+03
#   2.104800e+03 3.255300e+03 4.083300e+03 4.615800e+03 5.978300e+03
#   7.538800e+03 9.304900e+03 1.131070e+04 1.362860e+04 3.085670e+04
#   4.528590e+04 5.575000e+04 6.643530e+04 8.179430e+04 9.960460e+04
#   1.155992e+05 1.481993e+05 1.874256e+05 2.162831e+05 2.502506e+05
#   3.034155e+05 1.267696e+05]]

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D



plt.scatter(dataFr['wheat'], dataFr['Y'], color='green')
plt.title('Index Price Vs Agro product Rate', fontsize=14)
plt.xlabel('Agro product Rate', fontsize=14)
plt.ylabel('Index Price', fontsize=14)
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
colors = {'wheat':'tab:pink', 'barley':'tab:orange', 'corn':'tab:green', 'rice':'tab:purple',  'I':'tab:brown'}

# %%
import altair as alt


alt.Chart(dataFr).mark_circle().encode(
   x ='wheat', 
   y = 'Y',
   color=alt.ColorDatum(alt.repeat('layer'))
    
).interactive().repeat(
    layer=["wheat"])
# Out:
# alt.RepeatChart(...)

# %%
import altair as alt


plt1 = alt.Chart(dataFr).mark_circle(size=60, color='#ca5492').encode(x =alt.X('wheat', axis=alt.Axis(title='wheat')), y = 'Y', tooltip = 'Name:N').interactive()
plt2 = alt.Chart(dataFr).mark_circle(size=60, color='purple').encode(x =alt.X('barley', axis=alt.Axis(title='barley')), y = 'Y',).interactive()
plt3 = alt.Chart(dataFr).mark_circle(size=60, color='orange').encode(x ='corn', y = 'Y',).interactive()
plt4 = alt.Chart(dataFr).mark_circle(size=60, color='green').encode(x ='rice', y = 'Y',).interactive()
plt5 = alt.Chart(dataFr).mark_circle(size=60, color='red').encode(x ='legumes', y = 'Y',).interactive()

plt1 + plt2 + plt3 + plt4 + plt5
# Out:
# alt.LayerChart(...)

# %%
import altair as alt


alt.Chart(dataFr).mark_circle().encode(
   x ='wheat', 
   y = 'Y',
   opacity=alt.value(0.3),
   #color=alt.value('red')
    
).interactive()
# Out:
# alt.Chart(...)

# %%
import altair as alt
from vega_datasets import data
points = alt.Chart(dataFr).mark_point().encode(
    x ='wheat',
    y = 'Y',
    color=alt.condition(brush, 'Origin:N', alt.value('lightgray'))
).add_selection(
    brush
)

bars = alt.Chart(cars).mark_bar().encode(
    y = 'Y',
    color='Origin:N',
     x ='wheat
).transform_filter(
    brush
)

points & bars
# Out:
#   Input In [10]
#     x ='wheat
#              ^
# SyntaxError: EOL while scanning string literal

# %%
from vega_datasets import data
cars = data.cars()
cars.head()
# Out:
#                         Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0  chevrolet chevelle malibu              18.0          8         307.0
# 1          buick skylark 320              15.0          8         350.0
# 2         plymouth satellite              18.0          8         318.0
# 3              amc rebel sst              16.0          8         304.0
# 4                ford torino              17.0          8         302.0
#
#    Horsepower  Weight_in_lbs  Acceleration       Year Origin
# 0       130.0           3504          12.0 1970-01-01    USA
# 1       165.0           3693          11.5 1970-01-01    USA
# 2       150.0           3436          11.0 1970-01-01    USA
# 3       150.0           3433          12.0 1970-01-01    USA
# 4       140.0           3449          10.5 1970-01-01    USA

# %%
source = data.cars()

plt = alt.Chart(source).mark_circle(size=60).encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
    tooltip=['Horsepower', 'Miles_per_Gallon']
).interactive()

plt2 = alt.Chart(source).mark_circle(size=60).encode(
    x='Displacement',
    y='Miles_per_Gallon',
    color='Origin',
    tooltip=['Horsepower', 'Miles_per_Gallon']
).interactive()

plt + plt2
# Out:
# alt.LayerChart(...)

# %%
dataFr.head()
# Out:
#   Mahsulot turi        Y   wheat  barley   corn   rice  legumes  potato   \
# 0        1991 y    29.73   668.2   357.9  430.6  551.8      5.9    351.2
# 1        1992 y   216.40  1042.4   394.7  367.2  583.0      5.4    365.4
# 2        1993 y  1995.00   947.4   319.3  403.6  581.7      6.4    472.4
# 3        1994 y    32.80  1452.1   322.3  275.9  528.4      6.2    567.1
# 4        1995 y   124.40  2494.1   347.7  185.5  327.6      6.9    439.9
#
#    Sabzavotlar ? jami , ming tonna pomidor, ming tonna  ...  \
# 0                           3348.0               617.1  ...
# 1                           3494.3               526.8  ...
# 2                           3038.7               444.8  ...
# 3                           2975.3               487.8  ...
# 4                           2724.7               426.7  ...
#
#   parrandalar,tirik vaznda, ming tonna  \
# 0                                 62.8
# 1                                 36.4
# 2                                 29.9
# ...

# %%
brush = alt.selection_interval()

points = alt.Chart(dataFr).mark_point().encode(
    x='wheat:Q',
    y='Y:Q',
    color=alt.condition(brush, 'wheat:N', alt.value('lightgray'))
).add_selection(
    brush
)

bars = alt.Chart(cars).mark_bar().encode(
    y='wheat:N',
    color='wheat:N',
    x='count(wheat):Q'
).transform_filter(
    brush
)

points & bars
# Out:
# alt.VConcatChart(...)

# %%
import matplotlib.pyplot as plt

col = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

#data_X = array([dataFr['wheat'], dataFr['barley'], dataFr['corn'], dataFr['rice'], dataFr['legumes']])

plt.scatter(dataFr['wheat'], dataFr['Y'], c=col[0], label="wheat")
plt.scatter(dataFr['barley'], dataFr['Y'], c=col[1], label="barley")
plt.scatter(dataFr['corn'], dataFr['Y'], c=col[2], label="corn")
plt.scatter(dataFr['rice'], dataFr['Y'], c=col[3], label="rice")
plt.scatter(dataFr['legumes'], dataFr['Y'], c=col[4], label="legumes")

plt.legend()
plt.xlabel('Agrocultire products')
plt.ylabel("Volume of agricultural products ")
#plt.suptitle("Price vs Tonne")
plt.show()

# %%
col = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt1 = alt.Chart(dataFr).mark_circle(size=60, color=col[0]).encode(x =alt.X('wheat', axis=alt.Axis(title='wheat')), y = 'Y',  opacity=alt.value(0.2),).interactive()
plt2 = alt.Chart(dataFr).mark_circle(size=60, color=col[1]).encode(x =alt.X('barley', axis=alt.Axis(title='barley')), y = 'Y',opacity=alt.value(0.2),).interactive()
plt3 = alt.Chart(dataFr).mark_circle(size=60, color=col[2]).encode(x ='corn', y = 'Y',opacity=alt.value(0.2),).interactive()
plt4 = alt.Chart(dataFr).mark_circle(size=60, color=col[3]).encode(x ='rice', y = 'Y',opacity=alt.value(0.2),).interactive()
plt5 = alt.Chart(dataFr).mark_circle(size=60, color=col[4]).encode(x ='legumes', y = 'Y',opacity=alt.value(0.2),).interactive()

plt1 + plt2 + plt3 + plt4 + plt5
# Out:
# alt.LayerChart(...)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler,  Normalizer, MaxAbsScaler

data = array([dataFr['Y'], dataFr['wheat'], dataFr['barley'], dataFr['corn'], dataFr['rice'], dataFr['legumes']])

#norm = MinMaxScaler(feature_range=(0, 1))
norm = Normalizer()
scaled = norm.fit_transform(data)

Scdata = pd.DataFrame([[scaled[0], scaled[1], scaled[2], scaled[3], scaled[4], scaled[5]]], 
                      columns=['Y','wheat', 'barley', 'corn','rice','legumes'])
#df = pd.DataFrame(scaled)
#df.head()
with open('C:/Users/User/Desktop/ACM/new.csv', 'a') as fil:
     Scdata.to_csv(fil, index=False)
print(scaled)
#print("_________________________________________________________________________________ \n")
#print(scaled)
# Out:
# [[5.29141844e-05 3.85154037e-04 3.55075001e-03 5.83782459e-05
#   2.21410176e-04 3.22148247e-04 7.11751845e-04 9.79081495e-04
#   1.58671360e-03 2.46897264e-03 3.74617475e-03 5.79386292e-03
#   7.26755766e-03 8.21531424e-03 1.06403252e-02 1.34177415e-02
#   1.65610896e-02 2.01310617e-02 2.42565171e-02 5.49195128e-02
#   8.06009574e-02 9.92252197e-02 1.18243179e-01 1.45579505e-01
#   1.77278714e-01 2.05746296e-01 2.63768755e-01 3.33584688e-01
#   3.84945975e-01 4.45402166e-01 5.40026361e-01 2.25627649e-01]
#  [2.23554296e-02 3.48747378e-02 3.16963992e-02 4.85817409e-02
#   8.34430962e-02 9.62032890e-02 1.08036745e-01 1.24436972e-01
#   1.25698271e-01 1.23259314e-01 1.28592231e-01 1.73403459e-01
#   1.88211171e-01 1.84263340e-01 2.02650865e-01 2.04059371e-01
#   2.07103884e-01 2.05658577e-01 2.22142444e-01 2.25662036e-01
#   2.18368585e-01 2.21219053e-01 2.28907287e-01 2.32721293e-01
#   2.33012362e-01 2.32015367e-01 2.03386901e-01 1.81024780e-01
# ...

# %%
col = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

#data_X = array([dataFr['wheat'], dataFr['barley'], dataFr['corn'], dataFr['rice'], dataFr['legumes']])

plt.scatter(scaled[1], scaled[0], c=col[0], label="wheat")
plt.scatter(scaled[2], scaled[0], c=col[1], label="barley")
plt.scatter(scaled[3], scaled[0], c=col[2], label="corn")
plt.scatter(scaled[4], scaled[0], c=col[3], label="rice")
plt.scatter(scaled[5], scaled[0], c=col[4], label="legumes")

plt.legend()
plt.xlabel('Agrocultire products')
plt.ylabel("Volume of agricultural products ")
plt.show()
#print(scaled[1])

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
import math
#X = array(scaled[1:2])
#X = numpy.delete(scaled, scaled[0:1], axis=0)
dataFr = pd.read_csv('C:/Users/User/Desktop/ACM/OOZ2.csv')
X = dataFr[['wheat','barley', 'corn','rice','legumes']]
Y = dataFr['Y']

X_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(x_test)


mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
#ac = accuracy_score(y_test, y_pred, normalize = True, sample_weight = None)
rmse = math.sqrt(mse)

print(mae)
print(mape)
print(mse)
print('R²: %.2f' % r2_score(y_test, y_pred))

fig, ax = plt.subplots()
ax.scatter(y_test, y_pred)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('measured')
ax.set_ylabel('predicted')
plt.show()
# Out:
# 15487.55400233896
# 5.097803028639875
# 316097380.68261856
# R²: 0.98

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
import math
#X = array(scaled[1:2])
#X = numpy.delete(scaled, scaled[0:1], axis=0)

ScdataFr = pd.read_csv('C:/Users/User/Desktop/ACM/StandardScaler.csv')
X = ScdataFr[['wheat','barley', 'corn', 'rice', 'legumes']]
Y = ScdataFr['Y']

X_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(x_test)


mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
#ac = accuracy_score(y_test, y_pred, normalize = True, sample_weight = None)
rmse = math.sqrt(mse)

print("The slope is {} and the y intercept is {}".format(lr.coef_, lr.intercept_))

print("mean absolute error is: ",  mae)
print("mean absolute ercentage error is:  ", mape)
print("mean squared error is:   ", mse)
print('R²: %.2f' % r2_score(y_test, y_pred))
#r2 = lr.score(X, Y)
#print(r2 )
# Out:
# The slope is [-1.00495185 -0.82121019 -0.86976748 -1.21111076 -1.12433631] and the y intercept is -0.014518082807371213
# mean absolute error is:  0.009934256630976976
# mean absolute ercentage error is:   1.2829069078100694
# mean squared error is:    0.00033443760690711
# R²: 1.00

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, y_pred)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('StandardScaler measured')
ax.set_ylabel('predicted')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
import math
#X = array(scaled[1:2])
#X = numpy.delete(scaled, scaled[0:1], axis=0)

ScdataFr = pd.read_csv('C:/Users/User/Desktop/ACM/MinMaxScaler.csv')
X = ScdataFr[['wheat','barley', 'corn', 'rice', 'legumes']]
Y = ScdataFr['Y']

X_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(x_test)
ae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
#ac = accuracy_score(y_test, y_pred, normalize = True, sample_weight = None)
rmse = math.sqrt(mse)

print("The slope is {} and the y intercept is {}".format(lr.coef_, lr.intercept_))

print("mean absolute error is: ",  mae)
print("mean absolute precentage error is:  ", mape)
print("mean squared error is:   ", mse)
print('R²: %.2f' % r2_score(y_test, y_pred))
# Out:
# The slope is [ -0.4258076   -2.66075148   6.03004145  -3.41912776 -94.0219575 ] and the y intercept is 1.082303386704751
# mean absolute error is:  0.009934256630976976
# mean absolute precentage error is:   0.28654565896014744
# mean squared error is:    0.02584535984416472
# R²: 0.74

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, y_pred)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('MinMaxScaler measured')
ax.set_ylabel('predicted')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
import math
#X = array(scaled[1:2])
#X = numpy.delete(scaled, scaled[0:1], axis=0)

ScdataFr = pd.read_csv('C:/Users/User/Desktop/ACM/RobustScaler.csv')
X = ScdataFr[['wheat','barley', 'corn', 'rice', 'legumes']]
Y = ScdataFr['Y']

X_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(x_test)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
#ac = accuracy_score(y_test, y_pred, normalize = True, sample_weight = None)
rmse = math.sqrt(mse)

print("The slope is {} and the y intercept is {}".format(lr.coef_, lr.intercept_))

print("mean absolute error is: ",  mae)
print("mean absolute ercentage error is:  ", mape)
print("mean squared error is:   ", mse)
print('R²: %.2f' % r2_score(y_test, y_pred))
# Out:
# The slope is [-0.18487951 -1.81404249  0.25700195 -0.49586732 13.95606704] and the y intercept is 15.69271196431171
# mean absolute error is:  20.985339388865437
# mean absolute ercentage error is:   4.737497085164466
# mean squared error is:    759.9444090712562
# R²: -0.01

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, y_pred)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('RobustScaler measured')
ax.set_ylabel('predicted')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
import math
#X = array(scaled[1:2])
#X = numpy.delete(scaled, scaled[0:1], axis=0)

ScdataFr = pd.read_csv('C:/Users/User/Desktop/ACM/Normalizer.csv')
X = ScdataFr[['wheat','barley', 'corn', 'rice', 'legumes']]
Y = ScdataFr['Y']

X_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=42)

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(x_test)
ae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
#ac = accuracy_score(y_test, y_pred, normalize = True, sample_weight = None)
rmse = math.sqrt(mse)

print("The slope is {} and the y intercept is {}".format(lr.coef_, lr.intercept_))

print("mean absolute error is: ",  mae)
print("mean absolute ercentage error is:  ", mape)
print("mean squared error is:   ", mse)
print('R²: %.2f' % r2_score(y_test, y_pred))
# Out:
# The slope is [ 0.36568531 -0.10791404 -0.07050675  0.37131431  0.89339269] and the y intercept is -0.07561269458793794
# mean absolute error is:  20.985339388865437
# mean absolute ercentage error is:   5.117640707654572
# mean squared error is:    0.0010047928060432515
# R²: 0.98

# %%
fig, ax = plt.subplots()
ax.scatter(y_test, y_pred)
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Normalizer measured')
ax.set_ylabel('predicted')
plt.show()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
usmacro = pd.read_csv('C:/Users/User/Desktop/ACM/macrodata.csv', index_col=0, parse_dates=True)
usmacro.head()
usmacro1 = pd.read_csv('C:/Users/User/Desktop/ACM/OOZ2.csv')
usmacro1.head()
# Out:
#   Mahsulot turi        Y   wheat  barley   corn   rice  legumes  potato   \
# 0        1991 y    29.73   668.2   357.9  430.6  551.8      5.9    351.2
# 1        1992 y   216.40  1042.4   394.7  367.2  583.0      5.4    365.4
# 2        1993 y  1995.00   947.4   319.3  403.6  581.7      6.4    472.4
# 3        1994 y    32.80  1452.1   322.3  275.9  528.4      6.2    567.1
# 4        1995 y   124.40  2494.1   347.7  185.5  327.6      6.9    439.9
#
#    Sabzavotlar ? jami , ming tonna pomidor, ming tonna  ...  \
# 0                           3348.0               617.1  ...
# 1                           3494.3               526.8  ...
# 2                           3038.7               444.8  ...
# 3                           2975.3               487.8  ...
# 4                           2724.7               426.7  ...
#
#   parrandalar,tirik vaznda, ming tonna  \
# 0                                 62.8
# 1                                 36.4
# 2                                 29.9
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
#usmacro1.index.freq = 'MS'
usmacro1 = pd.read_csv('C:/Users/User/Desktop/ACM/Normalizer.csv')
train, test = usmacro1.iloc[:10, 5], usmacro1.iloc[10:, 5]
model = ExponentialSmoothing(train, trend='add', seasonal='mul', seasonal_periods=3, damped_trend=True)
hw_model = model.fit(optimized=True, remove_bias=True)
pred = hw_model.predict(start = test.index[0], end = test.index[-1])
print(train)

plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, label='Test')
plt.plot(pred.index, pred, label='Holt-Winters')
plt.xlabel("The number of years from 1991 to 2022 is 31 years")
plt.ylabel("Normalizer scaling value")
plt.legend(loc='best');
# Out:
# 0    0.00749
# 1    0.00686
# 2    0.00813
# 3    0.00787
# 4    0.00876
# 5    0.00952
# 6    0.01490
# 7    0.02490
# 8    0.01420
# 9    0.01170
# Name: legumes, dtype: float64

# %%
def model_eval(y, predictions):

    # Import library for metrics
    from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

    # Mean absolute error (MAE)
    mae = mean_absolute_error(y, predictions)

    # Mean squared error (MSE)
    mse = mean_squared_error(y, predictions)


    # SMAPE is an alternative for MAPE when there are zeros in the testing data. It
    # scales the absolute percentage by the sum of forecast and observed values
    SMAPE = np.mean(np.abs((y - predictions) / ((y + predictions)/2))) * 100


    # Calculate the Root Mean Squared Error
    rmse = np.sqrt(mean_squared_error(y, predictions))

    # Calculate the Mean Absolute Percentage Error
    # y, predictions = check_array(y, predictions)
    MAPE = np.mean(np.abs((y - predictions) / y)) * 100

    # mean_forecast_error
    mfe = np.mean(y - predictions)

    # NMSE normalizes the obtained MSE after dividing it by the test variance. It
    # is a balanced error measure and is very effective in judging forecast
    # accuracy of a model.

    # normalised_mean_squared_error
    NMSE = mse / (np.sum((y - np.mean(y)) ** 2)/(len(y)-1))


    # theil_u_statistic
    # It is a normalized measure of total forecast error.
    error = y - predictions
    mfe = np.sqrt(np.mean(predictions**2))
    mse = np.sqrt(np.mean(y**2))
    rmse = np.sqrt(np.mean(error**2))
    theil_u_statistic =  rmse / (mfe*mse)


    # mean_absolute_scaled_error
    # This evaluation metric is used to over come some of the problems of MAPE and
    # is used to measure if the forecasting model is better than the naive model or
    # not.


    # Print metrics
    
    
    print('Mean Absolute Error:', round(mae, 3))
    print('Mean absolute percentage error:', round(MAPE, 3))
    print('Mean Squared Error:', round(mse, 3))
    print('Root Mean Squared Error:', round(rmse, 3))
    print('Scaled Mean absolute percentage error:', round(SMAPE, 3))
    print('Mean forecast error:', round(mfe, 3))
    print('Normalised mean squared error:', round(NMSE, 3))
    print('Theil_u_statistic:', round(theil_u_statistic, 3))
    
print(model_eval(test, pred))
# Out:
# Mean Absolute Error: 0.108
# Mean absolute percentage error: 52.925
# Mean Squared Error: 0.213
# Root Mean Squared Error: 0.193
# Scaled Mean absolute percentage error: 81.92
# Mean forecast error: 0.028
# Normalised mean squared error: 1.314
# Theil_u_statistic: 32.852
# None
